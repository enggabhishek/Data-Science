# %%
from sklearn.linear_model import LogisticRegression as LR
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("titanic_x_y_train")

# %%
def Sex(string):
    if string == "male":
        return 0
    else:
        return 1

# %%
def Age(age):
    age = str(age)
    if age != "nan":
        return int(float(age))
    else:
        return 0

# %%
def Cabin(cabin):
    cabin = str(cabin)
    if cabin != "nan":
        return 1
    else:
        return 0

# %%
def Embarked(emb):
    emb = str(emb)
    if emb == "C":
        return 1
    elif emb == "Q":
        return 2
    elif emb == "S":
        return 3
    else:
        return 0

# %%
def change_dtype(datatype):
    datatype = str(datatype)
    if datatype != "nan":
        return int(float(datatype))
    else:
        return 0

# %%
new_data = pd.DataFrame()
new_data["Age"] = data["Age"].apply(Age)
new_data["Sex"] = data["Sex"].apply(Sex)
new_data["SibSp"] = data["SibSp"].apply(change_dtype)
new_data["Parch"] = data["Parch"].apply(change_dtype)
new_data["Fare"] = data["Fare"].apply(change_dtype)
new_data["Cabin"] = data["Cabin"].apply(Cabin)
new_data["Embarked"] = data["Embarked"].apply(Embarked)
new_data["Age_Age"] = new_data["Age"]*new_data["Age"]
new_data["Cabin_Embarked"] = new_data["Cabin"]*new_data["Embarked"]

# %%
x_train = np.array(new_data)
y_train = np.array(data["Survived"])

# %%
model = LR()
model.fit(x_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x_train, y_train)
# Out:
# 0.7904191616766467

# %%
test_data = pd.read_csv("titanic_x_test.csv")

# %%
x_test = pd.DataFrame()
x_test["Age"] = test_data["Age"].apply(Age)
x_test["Sex"] = test_data["Sex"].apply(Sex)
x_test["SibSp"] = test_data["SibSp"].apply(change_dtype)
x_test["Parch"] = test_data["Parch"].apply(change_dtype)
x_test["Fare"] = test_data["Fare"].apply(change_dtype)
x_test["Cabin"] = test_data["Cabin"].apply(Cabin)
x_test["Embarked"] = test_data["Embarked"].apply(Embarked)
x_test["Age_Age"] = x_test["Age"]*x_test["Age"]
x_test["Cabin_Embarked"] = x_test["Cabin"]*x_test["Embarked"]

# %%
x_test_array = np.array(x_test)
y_predict = model.predict(x_test_array)
model.score(x_train, y_train)
# Out:
# 0.7904191616766467

# %%
model.predict_proba(x_test_array)
# Out:
# array([[0.86545224, 0.13454776],
#        [0.11503896, 0.88496104],
#        [0.74281892, 0.25718108],
#        [0.46794724, 0.53205276],
#        [0.54911207, 0.45088793],
#        [0.82024337, 0.17975663],
#        [0.82813273, 0.17186727],
#        [0.74281892, 0.25718108],
#        [0.29249134, 0.70750866],
#        [0.81764239, 0.18235761],
#        [0.16097485, 0.83902515],
#        [0.81839767, 0.18160233],
#        [0.05758477, 0.94241523],
#        [0.30269909, 0.69730091],
#        [0.7104859 , 0.2895141 ],
#        [0.87288483, 0.12711517],
#        [0.83512601, 0.16487399],
#        [0.87783375, 0.12216625],
#        [0.83721331, 0.16278669],
#        [0.21030327, 0.78969673],
#        [0.233487  , 0.766513  ],
#        [0.78854846, 0.21145154],
#        [0.13707328, 0.86292672],
#        [0.38150467, 0.61849533],
#        [0.81839767, 0.18160233],
#        [0.45895234, 0.54104766],
#        [0.84444956, 0.15555044],
#        [0.88239351, 0.11760649],
#        [0.24395139, 0.75604861],
#        [0.39774089, 0.60225911],
#        [0.83448542, 0.16551458],
#        [0.98308175, 0.01691825],
#        [0.84320256, 0.15679744],
#        [0.85197891, 0.14802109],
#        [0.87358337, 0.12641663],
#        [0.24145714, 0.75854286],
#        [0.30134996, 0.69865004],
#        [0.81550715, 0.18449285],
#        [0.84643842, 0.15356158],
#        [0.59894841, 0.40105159],
#        [0.19434767, 0.80565233],
#        [0.83721331, 0.16278669],
#        [0.83657703, 0.16342297],
#        [0.84643842, 0.15356158],
#        [0.29728541, 0.70271459],
#        [0.48173575, 0.51826425],
#        [0.88685152, 0.11314848],
#        [0.19434767, 0.80565233],
#        [0.74539055, 0.25460945],
#        [0.68102437, 0.31897563],
#        [0.78159993, 0.21840007],
#        [0.21095198, 0.78904802],
#        [0.09800109, 0.90199891],
#        [0.19813198, 0.80186802],
#        [0.86074737, 0.13925263],
#        [0.89904841, 0.10095159],
#        [0.68315064, 0.31684936],
#        [0.85636453, 0.14363547],
#        [0.89053926, 0.10946074],
#        [0.73078122, 0.26921878],
#        [0.83001136, 0.16998864],
#        [0.62027386, 0.37972614],
#        [0.30545606, 0.69454394],
#        [0.19434767, 0.80565233],
#        [0.09062285, 0.90937715],
#        [0.89732822, 0.10267178],
#        [0.80898786, 0.19101214],
#        [0.61146133, 0.38853867],
#        [0.07877912, 0.92122088],
#        [0.65074907, 0.34925093],
#        [0.8344787 , 0.1655213 ],
#        [0.8481123 , 0.1518877 ],
#        [0.43762353, 0.56237647],
#        [0.84680053, 0.15319947],
#        [0.85270566, 0.14729434],
#        [0.04539668, 0.95460332],
#        [0.24639288, 0.75360712],
#        [0.76532269, 0.23467731],
#        [0.62665669, 0.37334331],
#        [0.89086279, 0.10913721],
#        [0.89306555, 0.10693445],
#        [0.10255175, 0.89744825],
#        [0.92249039, 0.07750961],
#        [0.66553506, 0.33446494],
#        [0.83628352, 0.16371648],
#        [0.2714976 , 0.7285024 ],
#        [0.47547984, 0.52452016],
#        [0.52343816, 0.47656184],
#        [0.83721331, 0.16278669],
#        [0.81839767, 0.18160233],
#        [0.27345835, 0.72654165],
#        [0.89936059, 0.10063941],
#        [0.85156533, 0.14843467],
#        [0.30742812, 0.69257188],
#        [0.74281892, 0.25718108],
#        [0.67798046, 0.32201954],
#        [0.87929594, 0.12070406],
#        [0.57691445, 0.42308555],
#        [0.93784939, 0.06215061],
#        [0.06932777, 0.93067223],
#        [0.19434767, 0.80565233],
#        [0.81688468, 0.18311532],
#        [0.05445823, 0.94554177],
#        [0.96311958, 0.03688042],
#        [0.27473338, 0.72526662],
#        [0.05683964, 0.94316036],
#        [0.9164538 , 0.0835462 ],
#        [0.85478599, 0.14521401],
#        [0.98308175, 0.01691825],
#        [0.83652066, 0.16347934],
#        [0.83192901, 0.16807099],
#        [0.10641583, 0.89358417],
#        [0.38026974, 0.61973026],
#        [0.59767589, 0.40232411],
#        [0.37132056, 0.62867944],
#        [0.89355793, 0.10644207],
#        [0.88620681, 0.11379319],
#        [0.19434767, 0.80565233],
#        [0.89094712, 0.10905288],
#        [0.81839767, 0.18160233],
#        [0.87622614, 0.12377386],
#        [0.81839767, 0.18160233],
#        [0.85514962, 0.14485038],
#        [0.83726949, 0.16273051],
#        [0.62225287, 0.37774713],
#        [0.91640554, 0.08359446],
#        [0.9172808 , 0.0827192 ],
#        [0.90657671, 0.09342329],
#        [0.96381636, 0.03618364],
#        [0.45895234, 0.54104766],
#        [0.87407542, 0.12592458],
#        [0.83377672, 0.16622328],
#        [0.76461407, 0.23538593],
#        [0.8380583 , 0.1619417 ],
#        [0.84675902, 0.15324098],
#        [0.81839767, 0.18160233],
#        [0.24175849, 0.75824151],
#        [0.46525784, 0.53474216],
#        [0.29249134, 0.70750866],
#        [0.62623042, 0.37376958],
#        [0.64926608, 0.35073392],
#        [0.84320256, 0.15679744],
#        [0.5627944 , 0.4372056 ],
#        [0.87257984, 0.12742016],
#        [0.76541813, 0.23458187],
#        [0.83875666, 0.16124334],
#        [0.83247385, 0.16752615],
#        [0.85699866, 0.14300134],
#        [0.19434767, 0.80565233],
#        [0.11125846, 0.88874154],
#        [0.01584759, 0.98415241],
#        [0.83105393, 0.16894607],
#        [0.6283577 , 0.3716423 ],
#        [0.8401243 , 0.1598757 ],
#        [0.27104607, 0.72895393],
#        [0.69364623, 0.30635377],
#        [0.64659107, 0.35340893],
#        [0.34096391, 0.65903609],
#        [0.83247385, 0.16752615],
#        [0.88855289, 0.11144711],
#        [0.81764239, 0.18235761],
#        [0.30854191, 0.69145809],
#        [0.41616974, 0.58383026],
#        [0.19434767, 0.80565233],
#        [0.07453266, 0.92546734],
#        [0.83582341, 0.16417659],
#        [0.79050175, 0.20949825],
#        [0.81839767, 0.18160233],
#        [0.42601939, 0.57398061],
#        [0.24844778, 0.75155222],
#        [0.30978861, 0.69021139],
#        [0.42554162, 0.57445838],
#        [0.31253823, 0.68746177],
#        [0.67214319, 0.32785681],
#        [0.08496587, 0.91503413],
#        [0.83721331, 0.16278669],
#        [0.88098408, 0.11901592],
#        [0.83001136, 0.16998864],
#        [0.79242626, 0.20757374],
#        [0.32681496, 0.67318504],
#        [0.84480142, 0.15519858],
#        [0.64926608, 0.35073392],
#        [0.96271904, 0.03728096],
#        [0.17039276, 0.82960724],
#        [0.18041117, 0.81958883],
#        [0.87056824, 0.12943176],
#        [0.32282533, 0.67717467],
#        [0.69910211, 0.30089789],
#        [0.06216208, 0.93783792],
#        [0.85334176, 0.14665824],
#        [0.83307236, 0.16692764],
#        [0.88013602, 0.11986398],
#        [0.14468597, 0.85531403],
#        [0.81764239, 0.18235761],
#        [0.86460959, 0.13539041],
#        [0.30993502, 0.69006498],
#        [0.07028753, 0.92971247],
#        [0.34181703, 0.65818297],
#        [0.36525942, 0.63474058],
#        [0.06686059, 0.93313941],
#        [0.48712268, 0.51287732],
#        [0.51456871, 0.48543129],
#        [0.83721331, 0.16278669],
#        [0.58300667, 0.41699333],
#        [0.74281892, 0.25718108],
#        [0.85373184, 0.14626816],
#        [0.81942371, 0.18057629],
#        [0.84320256, 0.15679744],
#        [0.10917388, 0.89082612],
#        [0.55624651, 0.44375349],
#        [0.76563823, 0.23436177],
#        [0.30047493, 0.69952507],
#        [0.83754352, 0.16245648],
#        [0.63424967, 0.36575033],
#        [0.28592559, 0.71407441],
#        [0.07178657, 0.92821343],
#        [0.83512601, 0.16487399],
#        [0.81764239, 0.18235761],
#        [0.87404831, 0.12595169],
#        [0.5881393 , 0.4118607 ],
#        [0.06471428, 0.93528572],
#        [0.87518807, 0.12481193],
#        [0.62531724, 0.37468276]])

# %%
np.savetxt("titanic_prediction.csv", y_predict, fmt = ("%.0f"))
